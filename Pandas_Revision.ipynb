# %%
import pandas as pd

# %%
df = pd.read_csv("/content/student_marks1 (2).csv")
df
# Out:
#      roll number                                 name  module_1 module_2  \
# 0   121910311004               VEDANTHAM SESHA SAAYEE      2.80     2.94
# 1   221910301001             AASHISH KUMAR PAGADIMARI      3.07     2.94
# 2   221910301002                         ABDUL SAMEER      3.47      2.8
# 3   221910301003                       ADITHYA RAJESH      3.34     2.67
# 4   221910301004                  ARJULA RUDWIK REDDY      2.80      2.4
# 5   221910301005                        AVATI ADITHYA      2.54     3.34
# 6   221910301006                        BARADI LOKESH      3.07     3.07
# 7   221910301007        BASIREDDY HARSHAVARDHAN REDDY      2.94     3.47
# 8   221910301008                BATHULA SAHITHI REDDY      2.67     2.27
# 9   221910301009        BATTHALAPALLI ANSRUTA SNIGDHA      3.34     3.07
# 10  221910301010                  BATTULA SAI ASWITHA      2.00     1.74
# 11  221910301011                      BEJUGAM SHRAVYA      3.34      3.6
# ...

# %%
data = {"city":["manglore","eluru","vizag"],
                 "temp":[25,45,35],
                 "wind":[10,9,12]}
df1=pd.DataFrame(data)
df1
# Out:
#        city  temp  wind
# 0  manglore    25    10
# 1     eluru    45     9
# 2     vizag    35    12

# %%
df2=pd.DataFrame({"city":["manglore","eluru","vizag"],
                 "temp":[28,43,40],
                 "wind":[14,13,10]})
df2
# Out:
#        city  temp  wind
# 0  manglore    28    14
# 1     eluru    43    13
# 2     vizag    40    10

# %%
df3 = pd.concat([df1,df2],ignore_index = True)
df3
# Out:
#        city  temp  wind
# 0  manglore    25    10
# 1     eluru    45     9
# 2     vizag    35    12
# 3  manglore    28    14
# 4     eluru    43    13
# 5     vizag    40    10

# %%
df3[1:4]
# Out:
#        city  temp  wind
# 1     eluru    45     9
# 2     vizag    35    12
# 3  manglore    28    14

# %%
df4 = pd.concat([df1,df2], keys=["df1","df2"])
df4
# Out:
#            city  temp  wind
# df1 0  manglore    25    10
#     1     eluru    45     9
#     2     vizag    35    12
# df2 0  manglore    28    14
#     1     eluru    43    13
#     2     vizag    40    10

# %%
df5 = df4.loc["df2"]
df5
# Out:
#        city  temp  wind
# 0  manglore    28    14
# 1     eluru    43    13
# 2     vizag    40    10

# %%
df6 = pd.concat([df1,df2], axis=1)
df6
# Out:
#        city  temp  wind      city  temp  wind
# 0  manglore    25    10  manglore    28    14
# 1     eluru    45     9     eluru    43    13
# 2     vizag    35    12     vizag    40    10

# %%
g = df3.groupby("city")
g

# %%
for city,city_df in g:
  print(city)
  print(city_df)
# Out:
# eluru
#     city  temp  wind
# 1  eluru    45     9
# 4  eluru    43    13
# manglore
#        city  temp  wind
# 0  manglore    25    10
# 3  manglore    28    14
# vizag
#     city  temp  wind
# 2  vizag    35    12
# 5  vizag    40    10

# %%
g.get_group("vizag")
# Out:
#     city  temp  wind
# 2  vizag    35    12
# 5  vizag    40    10

# %% [markdown]
# 02/06/2022

# %%
df10 = pd.read_csv("/content/example1.txt", sep = " ")
df10
# Out:
#    City  Temp  Wind
# 0  vskp   100     5
# 1   blr    70     5
# 2   hyd    50     7

# %%
df11 = pd.read_csv("/content/example1.txt", sep = " ", header = None) #taking away the dedualt heade and specifying it as 0 1 2
df11
# Out:
#       0     1     2
# 0  City  Temp  Wind
# 1  vskp   100     5
# 2   blr    70     5
# 3   hyd    50     7

# %%
df12 = pd.read_csv("/content/example1.txt", sep = " ", header = None, names=["City_name", "Temperature"," wind_speed"])
df12
# Out:
#   City_name Temperature  wind_speed
# 0      City        Temp        Wind
# 1      vskp         100           5
# 2       blr          70           5
# 3       hyd          50           7

# %%
df13 = pd.read_table("/content/example1.txt", delimiter=",")
df13
# Out:
#    Unnamed: 0  City  Temp  Wind
# 0           0  vskp   100     5
# 1           1   blr    70     5
# 2           2   hyd    50     7

# %%
# writing back to the dataframe
df13.to_csv("/content/example1.txt")

# %%
df.index
# Out:
# RangeIndex(start=0, stop=59, step=1)

# %%
for i in df.index:
  print(df["roll number"][i],df["name"][i],df["total_internal"][i])
# Out:
# 121910311004 VEDANTHAM SESHA SAAYEE 32
# 221910301001 AASHISH KUMAR PAGADIMARI 36
# 221910301002 ABDUL SAMEER 30
# 221910301003 ADITHYA RAJESH 32
# 221910301004 ARJULA RUDWIK REDDY 30
# 221910301005 AVATI ADITHYA 28
# 221910301006 BARADI LOKESH 35
# 221910301007 BASIREDDY HARSHAVARDHAN REDDY 31
# 221910301008 BATHULA SAHITHI REDDY 29
# 221910301009 BATTHALAPALLI ANSRUTA SNIGDHA 34
# 221910301010 BATTULA SAI ASWITHA 22
# 221910301011 BEJUGAM SHRAVYA 33
# 221910301012 BHANU PRABHATH ALAPATI 35
# 221910301013 BITRA BABY SRIJA 27
# 221910301014 C ISWARYA 37
# 221910301015 C S VENKATA ADITHYA 35
# 221910301016 CHANDUPATLA AISHWARYA 35
# 221910301017 CHINNAM ARYAN REDDY 33
# 221910301018 CHITTINEEDI VENKATA NAGA SAI PAVAN 16
# 221910301019 G NEHAL 38
# 221910301020 GALIPOTHULA JOY STEPHEN 27
# 221910301021 GANDIKOTA SRIKAR 36
# 221910301022 GANGISHETTY SAI HYNDAVEE 33
# 221910301023 GEETIKA SAI MANNE 32
# 221910301025 HIRANYA VAISHNAVI BANDI 33
# 221910301026 INDELA MAHIDHAR REDDY 34
# ...

# %%
for i in range(len(df)):
  print(df.loc[i,"roll number"])
# Out:
# 121910311004
# 221910301001
# 221910301002
# 221910301003
# 221910301004
# 221910301005
# 221910301006
# 221910301007
# 221910301008
# 221910301009
# 221910301010
# 221910301011
# 221910301012
# 221910301013
# 221910301014
# 221910301015
# 221910301016
# 221910301017
# 221910301018
# 221910301019
# 221910301020
# 221910301021
# 221910301022
# 221910301023
# 221910301025
# 221910301026
# 221910301027
# 221910301028
# 221910301029
# 221910301030
# 221910301031
# 221910301032
# 221910301033
# 221910301034
# 221910301035
# 221910301036
# 221910301037
# 221910301038
# 221910301040
# 221910301041
# 221910301042
# 221910301043
# 221910301044
# 221910301045
# 221910301046
# 221910301047
# 221910301048
# 221910301050
# 221910301051
# 221910301052
# 221910301053
# 221910301054
# 221910301055
# 221910301056
# 221910301057
# 221910301058
# 221910301059
# 221910301060
# 221910301061

# %%
for i in range(len(df)):
  print(df.loc[i,"total_internal"])
# Out:
# 32
# 36
# 30
# 32
# 30
# 28
# 35
# 31
# 29
# 34
# 22
# 33
# 35
# 27
# 37
# 35
# 35
# 33
# 16
# 38
# 27
# 36
# 33
# 32
# 33
# 34
# 36
# 34
# 34
# 35
# 33
# 29
# 33
# 34
# 32
# 35
# 29
# 27
# 34
# 35
# 34
# 34
# 33
# 38
# 35
# 27
# 34
# 38
# 32
# 27
# 32
# 34
# 31
# 31
# 31
# 28
# 31
# 28
# 31
